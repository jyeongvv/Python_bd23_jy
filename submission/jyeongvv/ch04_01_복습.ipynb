# %% [markdown]
# <a href="https://colab.research.google.com/github/jyeongvv/Python_jy/blob/main/submission/jyeongvv/ch04_01_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 패키지나 모듈을 불러오는 키워드 import
# 패키지나 모듈 안에 있는 것을 부분적으로 불러오기 위해서는 from (패키지 또는 모듈명) import 불러오려는 모듈. 함수. 변수명...
# 불러올 때, 다른 이름을 지정해주고 싶으면 as : import...as... / from...import...as
# 특정 모듈이나 패키지 안에 있는 모든 항목들을 불러오려면 from...import *.
# !pip install .. !pip install ... -q(--quiet) / !pip uninstall ... / !pip install ... -u
# !pip list

# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.4
# aiosignal                     1.3.1
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.1
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# backports.zoneinfo            0.2.1
# ...

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ...

# %%
# from 패키지명 import 클래스 as 변수명
from gtts import gTTS as gs

tts = gs('hello', lang='en')
tts.save('hello.mp3')

# %%
tts = gs('안녕', lang='ko')
tts.save('hello_kr.mp3')

# %%
from Python.display import Audio

audio = Audio("hello_kr.mp3", autoplay = True)
display(audio)

# %%
from gtts import gTTS
from Python.display import Audio
